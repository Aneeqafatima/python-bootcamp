# %% [markdown]
# # Assignment 2
# Instructions
# Complete all the exercises below. Each section corresponds to the concepts covered in class. Write your code in the designated cells and test your solutions.

# %% [markdown]
# Exercise 1: Shopping List Calculator <br>
# Topics Covered: Lists, Input, Arithmetic Operators, Strings, Print, Type Casting
#
# Task:
#
# Write a program that:
#
# - Asks the user to input the names and prices of 3 items (names as strings, prices as strings converted to floats using type casting).
# - Stores these in a list of sublists, e.g., [["apple", 0.5], ["bread", 1.2], ["milk", 2.0]].
# - Calculates the total cost by directly accessing list elements (e.g., list[0][1]) with arithmetic operators.
# - Prints each item and its price (e.g., "Item: apple - Price: $0.50") and the total cost in a formatted way using the print() function.
#
# Bonus Challenge:
# Ask the user for a tax rate (e.g., 5%) as input, convert it to a float, and add the tax amount to the total (tax = total * (rate / 100)).

# %%
#ask the user to input the names and prices
item1_name=input("enter the name of items 1:")
item1_price=float(input("enter the price of item 1:"))

item2_name=input("enter the name of items 2:")
item2_price=float(input("enter the price of item 2:"))

item3_name=input("enter the name of items 3:")
item3_price=float(input("enter the prices of item 3:"))

#store the items in a list of sublists

items =[["apple",0.5],["bread",1.2],["milk",2.0]]

#calculate the total cost 
total_items_price=item1_price+item2_price+item3_price

#print each items in there price
print("items:",items[0][0],"price:",items[0][1])
print("items:",items[1][0],"price:",items[1][1])
print("items:",items[2][0],"price:",items[2][1])
print("total:",total)

#ask the user for a tax rate
tax_rate=input()
tax_rate=float(tax_rate)
tax_amount=total*(tax_rate/100)
total_amount=total+tax_amount
print("tax amount:",tax_amount)
print("total amount:",total_amount)

# %% [markdown]
# Exercise 2: Student Grade Manager <br>
# Topics Covered: Lists, List Methods, Indexing, Input, Type Casting, Variables, Print
#
# Task:
#
# Write a program that:
#
# - Creates a list called grades with exactly 3 predefined scores (e.g., [85.5, 90.0, 78.5]).
# - Asks the user to input 1 additional score (as a string, converted to a float) and adds it to the list using the append() method.
# - Uses indexing to print the first score and the last score.
# - Calculates the average of the 4 scores by adding them with arithmetic operators and dividing by 4.
# - Uses the sort() method to sort the list and prints the sorted list.
#
# Bonus Challenge:
# Use the insert() method to add a bonus score of 5.0 at the start of the list and print the updated list.

# %%
#create a list by predifined scores
grade=[85.5,90.0,78.5]
# ask the user for additional scoore and append it
new_score=float(input("enter additional score:"))
grade.append(new_score)

#print the first and the last score using indexing 
print("first score:grade[0]")
print("last score:grade[-1]")

#calculate the average af the 4 scores by adding them arithemetic operator and dividing by 4
average_score=sum(grade)/len(grade)
print("average_score:",average_score)

#use the sort()method to sort the list and print the list
grade.sort()
print("sorted list:",grade)

#bonus challenge:use the insert()method to add a bonus score of 5.0 at the start of the list and print the updated list
grade.insert(0,5.0)
print("updated list of grades")

# %% [markdown]
# Exercise 3: Word Slicer <br>
# Topics Covered: Strings, Lists, Slicing, Indexing, Input, Print, Datatypes
#
# Task:
#
# Write a program that:
#
# - Asks the user to input a sentence with at least 4 words (e.g., "I love to code").
# - Converts the sentence into a list of words using the split() method.
# - Uses slicing to print:
# - The first 2 words.
# - The last 2 words.
# - Uses indexing to print the third word.
# - Prints the total number of words using len() and the datatype of the list using type().
#
# Bonus Challenge:
# Create a new string by concatenating the first and last words from the list (e.g., "I code") and print it.

# %%
#ask a user to input a sentence with ateast 4 words
sentence=("hello how are you")

#convert the sentence into te list of words using the split()method
words=("hello","how","are","you")
words=sentence.split()

#use slicing to print the first 2 words and the last 2 words
print("first 2 words:",words[:2])
print("last 2 words:",words[-2:])

#use indexing b to print   3 word
print("third word:",words[2])

#print the total numbers of words using len() and the data type of the list using type()
print=(len(words))
print=(type(words))

#bonus challenge:create a new string by concatenating the first and last words from the list
new_string=words[0]+""+words[-1]
print(new_string)

# %% [markdown]
# Exercise 4: Name Analyzer <br>
# Topics Covered: Strings, Lists, Slicing, Indexing, Input, Print, List Methods
#
# Task:
#
# Write a program that:
#
# - Asks the user to input a full name with exactly 3 parts (e.g., "John Adam Smith").
# - Splits the name into a list of individual names using split().
# - Uses indexing to print the first name and last name.
# - Uses slicing to print the middle name.
# - Creates a new list with the lengths of each name (e.g., [len(names[0])]) and prints it.
# - Calculates and prints the total number of characters by adding the lengths.
#
# Bonus Challenge:
# Use the pop() method to remove the middle name and print the updated list (e.g., ["John", "Smith"]).

# %%
#get full name input from user
full_name=input("john adam smith")

#split the name into the list
name=("john","adam","smith")
name=full_name.split()

#print first and the last name using indexing
print("first name:",name[0])
print("last name:",name[2])

#print middle name using slicing
print("midle name:",name[1])

#create the list of lenghths and print it 
name1="john"
name2="adam"
name3="smith"
list=[len(name1)],[len(name2)],[len(name3)]
print=("name of lenghts")

#calculate and print the total number of characters adding lenghts
total_characters=len(name1)+len(name2)+len(name3)
print=("total numbers of character")

#bonus challenge
#use the pop()method
name.pop(1)
print("updated list after removing middle name")

# %% [markdown]
# Exercise 5: Employee Database Manager <br>
# Topics Covered: Dictionaries with Lists as Values, Dictionary Methods, List Operations, Sorting
# Task:
# Write a program that:
#
# - Creates a dictionary called employee_data with keys "names", "departments", and "salaries" where values are lists (e.g., {"names": ["Alice", "Bob", "Carol"], "departments": ["IT", "HR", "Finance"], "salaries": [75000, 65000, 80000]}).
# - Asks the user to input a new employee name and appends it to the "names" list.
# - Convert the dictionary keys to a list and prints it.
# - Sorts the names list using and prints the updated dictionary.
# - Uses indexing to print the first employee's name and salary.
# - Converts .values() to a list and prints the total number of data categories
#
# Bonus Challenge:
# Create a sorted list of department keys using sorted(list(employee_data.keys())) and print it.

# %%
employee_data={
    "names":["alice","bob","carol"],
    "department":["IT","HR","Finance"],
    "Salaries":[75000,65000,80000]
      }
employee_name=input("enter employee name")
["names"].append(employee_name)
employee_data_list=list(employee_data)
print(employee_data_list)
sortedlist=sorted(employee_data_list)
print("sorted dic",sortedlist)
print("first employee name",employee_data["names"][0])
print("first employee salary",employee_data["salaries"][0])
value_list=list(employee_data.value())
print("lenght of data categories",len(value_list))
sortedlist_departement=list(employee_data.key())
print("sorted list of departement",sortedlist_departement)
# Out:
# ['names', 'department', 'Salaries']
# sorted dic ['Salaries', 'department', 'names']
# first employee name alice
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 13
#      11 print("sorted dic",sortedlist)
#      12 print("first employee name",employee_data["names"][0])
# ---> 13 print("first employee salary",employee_data["salaries"][0])
#      14 value_list=list(employee_data.value())
#      15 print("lenght of data categories",len(value_list))
#
# KeyError: 'salaries'

# %% [markdown]
# Exercise 6: Student Course Tracker <br>
# Topics Covered: Dictionaries, Input, Dictionary Methods, String Operations, Conditional Logic
# Task:
# Write a program that:
#
# - Creates a dictionary called library_books with keys "title", "author", "isbn", and "available" with initial values (e.g., {"title": "1984", "author": "George Orwell", "isbn": "978-0451524935", "available": True}).
# - Asks the user to input a new ISBN number and updates the "isbn" value in the dictionary.
# - Uses the get() method to safely retrieve and print the "author" value, with a default message if the key doesn't exist.
# - Toggles the "available" status from True to False (or vice versa) using indexing.
# - Uses the pop() method to remove and print the "isbn" key-value pair.
# - Prints the final dictionary using items() method in a formatted way.
#
# Bonus Challenge:
# Ask the user if they want to add a "genre" key, and if yes, prompt for input and add it to the dictionary using setdefault() method.
#
# Reference: https://www.w3schools.com/python/python_ref_dictionary.asp

# %%
library_book={
    "title":1984,
    "author":"george orwell",
    "isbn":978_451524935,
    "available":True
}
print("actual library",library_book)
new_isbn=input(("enter your isbn"))
library_book["isbn"]=new_isbn
x=library_book.get("author")
print("author:",x)
library_book["available"]=not library_book["available"]
print("updated availability",library_book["available"])
values_list=list(library_book.values())
print(values_list[3])
removed_isbn=library_book.pop("isbn")
print("removed isbn:",removed_isbn)
print("the library_books is:",library_book.items())
add_genre=input("do u want to add a genre?(yes/no):")
if add_genre.lower()=="yes":
    genre=input("enter genre:")
    library_book.setdefault("genre",genre)
print("updated dictionary",library_book)
# Out:
# actual library {'title': 1984, 'author': 'george orwell', 'isbn': 978451524935, 'available': True}
# author: george orwell
# updated availability False
# False
# removed isbn:
# the library_books is: dict_items([('title', 1984), ('author', 'george orwell'), ('available', False)])
# updated dictionary {'title': 1984, 'author': 'george orwell', 'available': False}

# %% [markdown]
# Exercise 7: Restaurant Order System <br>
# Topics Covered: Dictionaries with Lists, List Indexing, Dictionary Methods, Sorting
# Task:
# Write a program that:
#
# - Creates a dictionary called orders with keys "items", "quantities", and "prices" where values are lists (e.g., {"items": ["Pizza", "Burger", "Salad"], "quantities": [2, 1, 3], "prices": [12.99, 8.50, 6.75]}).
# - Add a new item to the orders.
# - Get all keys as a list and prints the first key using indexing.
# - Accesses and prints the third item and its quantity using indexing
# - Converts the .values() method to a list and prints it.
# - Sorts the items list and prints the updated dictionary.
#
# Bonus Challenge:
# Create a sorted list of all keys

# %%
item1=input("enter item")
item2=input("enter item")
item3=input("enter item")
quantite1=int(input("enter quantity"))
quantite2=int(input("enter quantity"))
quantite3=int(input("enter quantity"))
price1=float(input("enter price"))
price2=float(input("enter price"))
price3=float(input("enter price"))
my_dic={
    "items":[item1,item2,item3],
    "quantities":[quantite1,quantite2,quantite3],
    "prices":[price1,price2,price3]
}
print(my_dic)
newitem=input("enter item")
my_dic["items"].append(newitem)
print("the new item is:",my_dic)
my_list=list(my_dic.keys())
print(my_list)
my_list_values=list(my_dic.values())
print(my_list_values)
print("accessing first key :",my_list[0])
print("access the third item :",my_list[2])
print("access the third quantitiy:",my_list_values[2])
my_dic["items"].sort()
print("sorted item list",my_dic)
sorted_keys=sorted(my_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 item2=input("enter item")
#       3 item3=input("enter item")
# ----> 4 quantities1=int(input("enter quantity"))
#       5 quantities2=int(input("enter quantity"))
#       6 quantities3=int(input("enter quantity"))
#
# ValueError: invalid literal for int() with base 10: ''
